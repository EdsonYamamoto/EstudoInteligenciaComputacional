# %% [markdown]
# # Aula 02 - Análise Exploratória de Dados
#
# ---

# %%
import numpy as np
import pandas as pd

df_dataset = pd.read_csv('iris.csv', sep=',', index_col=None)

# %% [markdown]
# ---
#
# Retomando a aula anterior, esse material aborda como fazer a exploração dos dados e conhecer características que podem distinguir uma classe de outra.

# %%
df_dataset.shape
# Out:
# (150, 5)

# %%
df_dataset.head(n=5)
# Out:
#    comprimento_sepala  largura_sepala  comprimento_petala  largura_petala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#         classe
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# ---
#
# A função describe() de um DataFrame auxilia a entender algumas medidas estatísticas que descrevem os dados. Serve para entender se uma distribuição é muito diferente de outra e se existe ou não a presença de pontos incomuns.

# %%
df_dataset.describe()
# Out:
#        comprimento_sepala  largura_sepala  comprimento_petala  largura_petala
# count          150.000000      150.000000          150.000000      150.000000
# mean             5.843333        3.054000            3.758667        1.198667
# std              0.828066        0.433594            1.764420        0.763161
# min              4.300000        2.000000            1.000000        0.100000
# 25%              5.100000        2.800000            1.600000        0.300000
# 50%              5.800000        3.000000            4.350000        1.300000
# 75%              6.400000        3.300000            5.100000        1.800000
# max              7.900000        4.400000            6.900000        2.500000

# %%
classe = df_dataset["classe"]
classe.describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: classe, dtype: object

# %%
classe.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df_amostrasSetosa = df_dataset[ df_dataset["classe"] == "Iris-setosa"]
df_amostrasSetosa.shape
# Out:
# (50, 5)

# %% [markdown]
# ---
#
# Em um determinado momento, pode ser interessante a análise para verificar se uma classe específica difere muito da descrição do conjunto de dados como um todo.

# %%
display(df_dataset.describe())
display(df_amostrasSetosa.describe())
# Out:
#        comprimento_sepala  largura_sepala  comprimento_petala  largura_petala
# count          150.000000      150.000000          150.000000      150.000000
# mean             5.843333        3.054000            3.758667        1.198667
# std              0.828066        0.433594            1.764420        0.763161
# min              4.300000        2.000000            1.000000        0.100000
# 25%              5.100000        2.800000            1.600000        0.300000
# 50%              5.800000        3.000000            4.350000        1.300000
# 75%              6.400000        3.300000            5.100000        1.800000
# max              7.900000        4.400000            6.900000        2.500000
#        comprimento_sepala  largura_sepala  comprimento_petala  largura_petala
# count            50.00000       50.000000           50.000000        50.00000
# mean              5.00600        3.418000            1.464000         0.24400
# std               0.35249        0.381024            0.173511         0.10721
# min               4.30000        2.300000            1.000000         0.10000
# 25%               4.80000        3.125000            1.400000         0.20000
# 50%               5.00000        3.400000            1.500000         0.20000
# 75%               5.20000        3.675000            1.575000         0.30000
# max               5.80000        4.400000            1.900000         0.60000

# %%
# encontra as classes do conjunto
from collections import Counter

print('Classes e quantidade:', Counter(df_dataset['classe']))
# Out:
# Classes e quantidade: Counter({'Iris-setosa': 50, 'Iris-versicolor': 50, 'Iris-virginica': 50})

# %%
df_dataset.boxplot(figsize=(15,7))
# mais informacoes sobre boxplot: https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# matriz de gráficos scatter 
sns.pairplot(df_dataset, hue='classe', height=3.5); # size -> height

# mostra o gráfico usando a função show() da matplotlib
plt.show()

# %%
#scatter plot
sns.lmplot(x='comprimento_sepala', y='largura_petala', data=df_dataset, 
           fit_reg=False,
           hue='classe')

# cria um título para o gráfico
plt.title('Comprimento vs largura da sépala.')

# mostra o gráfico
plt.show()

# %%
# define a dimensão do gráfico
plt.figure(figsize=(10,7))

# cria o boxplot
sns.boxplot(x="classe", y="comprimento_sepala", data=df_dataset, whis=1.5)

#mostra o gráfico
plt.show()

# %%
# cria um gráfico de barras com a frequência de cada classe
sns.countplot(x="classe", data=df_dataset)

# mostra o gráfico
plt.show()

# %%
mean = df_dataset.mean()

std = df_dataset.std()

# criando um gráfico de barras vertical
plt.figure(figsize=(10,5))
mean.plot(kind="bar", rot=0, color="red", fontsize=13, yerr=std);
plt.show()

# criando um gráfico de barras horizontal
plt.figure(figsize=(10,5))
mean.plot(kind="barh", rot=0, color="red", fontsize=13, xerr=std);
plt.show()

# %%
# cria o histograma
n, bins, patches = plt.hist(df_dataset['comprimento_petala'].values, bins=20, color='red', edgecolor='black', linewidth=0.9)

#mostra o gráfico
plt.show()

# %% [markdown]
# ## Correlação

# %%
# criando uma matriz X com os valores do data frame
X = df_dataset.iloc[:,:-1].values # exceto a coluna da classe (a última = -1)

# com pandas
# matriz de correlação
df_correlation = df_dataset.corr()

print('\n\nMatriz de correlação: ')
display(df_correlation)

# cria um mapa de cores dos valoes da correlação
sns.heatmap(df_correlation, annot=True,
        xticklabels=df_correlation.columns,
        yticklabels=df_correlation.columns)

plt.title('Correlação')
plt.show()
# Out:
# Matriz de correlação:
#                     comprimento_sepala  largura_sepala  comprimento_petala  \
# comprimento_sepala            1.000000       -0.109369            0.871754
# largura_sepala               -0.109369        1.000000           -0.420516
# comprimento_petala            0.871754       -0.420516            1.000000
# largura_petala                0.817954       -0.356544            0.962757
#
#                     largura_petala
# comprimento_sepala        0.817954
# largura_sepala           -0.356544
# comprimento_petala        0.962757
# largura_petala            1.000000

# %% [markdown]
# ### Exercício: crie uma regra que categoriza as amostras e compare a resposta obtida com a regra e a resposta original da base de dados (espécie).

# %%
from sklearn.model_selection import train_test_split


X = df_dataset.iloc[:,:-1].values
y = df_dataset["classe"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=201) # 70% treino e 30% teste

display(X_train, y_train)
# Out:
# array([[4.8, 3.4, 1.9, 0.2],
#        [7.4, 2.8, 6.1, 1.9],
#        [6.7, 3. , 5. , 1.7],
#        [5. , 3.4, 1.6, 0.4],
#        [4.4, 2.9, 1.4, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [7.7, 2.8, 6.7, 2. ],
#        [5.7, 2.8, 4.1, 1.3],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.7, 3. , 4.2, 1.2],
#        [6.3, 3.3, 6. , 2.5],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.9, 3. , 5.1, 1.8],
#        [4.5, 2.3, 1.3, 0.3],
#        [5.1, 3.5, 1.4, 0.2]])
# 24         Iris-setosa
# 130     Iris-virginica
# 77     Iris-versicolor
# 26         Iris-setosa
# 8          Iris-setosa
# 15         Iris-setosa
# 122     Iris-virginica
# 99     Iris-versicolor
# 9          Iris-setosa
# 95     Iris-versicolor
# 100     Iris-virginica
# 97     Iris-versicolor
# 149     Iris-virginica
# 41         Iris-setosa
# 0          Iris-setosa
# Name: classe, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = knn.predict(X_test)
display(y_pred)
# Out:
# array(['Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor'], dtype=object)

# %%
from sklearn import metrics
print("Acurácia:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Acurácia: 0.9037037037037037

# %%
cols = df_dataset.columns
numeric_columns = []

## varre as colunas procurando as regras no nome

for c in cols:
    if 'CR' in c or '%' in c:
        numeric_columns.append(c)

## cria uma cópia para não precisa reimportar se algo der errado
## e para cada coluna entendida como numérica, aplica o replace e a transformação pd.to_numeric
        
new_train = df_dataset.copy()    
for c in numeric_columns: 
    new_train[c] = pd.to_numeric(train[c].str.replace(',','.'))
        
new_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# comprimento_sepala    150 non-null float64
# largura_sepala        150 non-null float64
# comprimento_petala    150 non-null float64
# largura_petala        150 non-null float64
# classe                150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
## Ou podemos ter uma regra mais complexa

new_train['pred'] = 'Não'
indices_regra_predicao = (new_train['comprimento_petala'] >= 0.6) & (new_train['comprimento_petala'] <= 2.0)
new_train['pred'][indices_regra_predicao] = 'Iris-setosa'


indices_regra_predicao = (new_train['largura_petala'] >= 0.9) & (new_train['largura_petala'] <= 1.5)
new_train['pred'][indices_regra_predicao] = 'Iris-versicolor'


indices_regra_predicao = (new_train['largura_petala'] > 1.5)
new_train['pred'][indices_regra_predicao] = 'Iris-virginica'
# Out:
# C:\Users\edson\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\edson\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\edson\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
from collections import Counter
print(Counter(new_train['pred']))
print(Counter(new_train['classe']))
# Out:
# Counter({'Iris-virginica': 52, 'Iris-setosa': 50, 'Iris-versicolor': 48})
# Counter({'Iris-setosa': 50, 'Iris-versicolor': 50, 'Iris-virginica': 50})

# %%
i=new_train[new_train['pred']!=new_train['classe']]
i
# Out:
#      comprimento_sepala  largura_sepala  comprimento_petala  largura_petala  \
# 56                  6.3             3.3                 4.7             1.6
# 70                  5.9             3.2                 4.8             1.8
# 77                  6.7             3.0                 5.0             1.7
# 83                  6.0             2.7                 5.1             1.6
# 85                  6.0             3.4                 4.5             1.6
# 119                 6.0             2.2                 5.0             1.5
# 133                 6.3             2.8                 5.1             1.5
# 134                 6.1             2.6                 5.6             1.4
#
#               classe             pred
# 56   Iris-versicolor   Iris-virginica
# 70   Iris-versicolor   Iris-virginica
# 77   Iris-versicolor   Iris-virginica
# 83   Iris-versicolor   Iris-virginica
# 85   Iris-versicolor   Iris-virginica
# 119   Iris-virginica  Iris-versicolor
# 133   Iris-virginica  Iris-versicolor
# 134   Iris-virginica  Iris-versicolor

# %%
acertos = new_train['pred'] == new_train['classe']
acertos.sum() / acertos.count()
# Out:
# 0.9466666666666667
